# %%
# Model 5 – Lasso Regression

lasso = Lasso(alpha=0.01, random_state=42)

lasso_model, lasso_pred = evaluate_model(
    "Lasso Regression",
    lasso,
    X_train_scaled,
    X_test_scaled,
    y_train,
    y_test
)
# Out:
# Lasso Regression
# ----------------------------------------
# MAE         : 0.5353
# MSE         : 0.5483
# RMSE        : 0.7404
# R²          : 0.5816
# Adjusted R² : 0.5808
