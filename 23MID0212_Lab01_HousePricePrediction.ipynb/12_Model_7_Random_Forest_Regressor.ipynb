# %%
# Model 7 – Random Forest Regressor

forest = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

forest_model, forest_pred = evaluate_model(
    "Random Forest",
    forest,
    X_train,
    X_test,
    y_train,
    y_test
)
# Out:
# Random Forest
# ----------------------------------------
# MAE         : 0.3275
# MSE         : 0.2554
# RMSE        : 0.5053
# R²          : 0.8051
# Adjusted R² : 0.8047

# %%
results
# Out:
#                         Model       MAE       MSE      RMSE  R2 Score  \
# 0             Dummy Regressor  0.906069  1.310696  1.144856 -0.000219
# 1    Simple Linear Regression  0.629909  0.709116  0.842090  0.458859
# 2  Multiple Linear Regression  0.533200  0.555892  0.745581  0.575788
# 3            Ridge Regression  0.533193  0.555855  0.745557  0.575816
# 4            Lasso Regression  0.535326  0.548255  0.740442  0.581615
# 5               Decision Tree  0.454679  0.495235  0.703729  0.622076
# 6               Random Forest  0.327543  0.255368  0.505340  0.805123
#
#    Adjusted R2
# 0    -0.002162
# 1     0.458728
# 2     0.574964
# 3     0.574992
# 4     0.580803
# 5     0.621342
# 6     0.804745

# %%
results.round(4)
# Out:
#                         Model     MAE     MSE    RMSE  R2 Score  Adjusted R2
# 0             Dummy Regressor  0.9061  1.3107  1.1449   -0.0002      -0.0022
# 1    Simple Linear Regression  0.6299  0.7091  0.8421    0.4589       0.4587
# 2  Multiple Linear Regression  0.5332  0.5559  0.7456    0.5758       0.5750
# 3            Ridge Regression  0.5332  0.5559  0.7456    0.5758       0.5750
# 4            Lasso Regression  0.5353  0.5483  0.7404    0.5816       0.5808
# 5               Decision Tree  0.4547  0.4952  0.7037    0.6221       0.6213
# 6               Random Forest  0.3275  0.2554  0.5053    0.8051       0.8047

# %%
best_model = results.loc[
    results["R2 Score"].idxmax()
]

print(best_model)
# Out:
# Model          Random Forest
# MAE                 0.327543
# MSE                 0.255368
# RMSE                 0.50534
# R2 Score            0.805123
# Adjusted R2         0.804745
# Name: 6, dtype: object

# %%
results = results.sort_values(
    by="R2 Score",
    ascending=False
)

results.reset_index(
    drop=True,
    inplace=True
)

results.round(4)
# Out:
#                         Model     MAE     MSE    RMSE  R2 Score  Adjusted R2
# 0               Random Forest  0.3275  0.2554  0.5053    0.8051       0.8047
# 1               Decision Tree  0.4547  0.4952  0.7037    0.6221       0.6213
# 2            Lasso Regression  0.5353  0.5483  0.7404    0.5816       0.5808
# 3            Ridge Regression  0.5332  0.5559  0.7456    0.5758       0.5750
# 4  Multiple Linear Regression  0.5332  0.5559  0.7456    0.5758       0.5750
# 5    Simple Linear Regression  0.6299  0.7091  0.8421    0.4589       0.4587
# 6             Dummy Regressor  0.9061  1.3107  1.1449   -0.0002      -0.0022

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=results,
    x="Model",
    y="R2 Score"
)

plt.xticks(rotation=30)

plt.title("Comparison of Regression Models")

plt.show()
