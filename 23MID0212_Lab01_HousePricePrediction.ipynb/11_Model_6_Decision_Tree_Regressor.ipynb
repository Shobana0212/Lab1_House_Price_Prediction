# %%
# Model 6 – Decision Tree Regressor

tree = DecisionTreeRegressor(
    random_state=42
)

tree_model, tree_pred = evaluate_model(
    "Decision Tree",
    tree,
    X_train,
    X_test,
    y_train,
    y_test
)
# Out:
# Decision Tree
# ----------------------------------------
# MAE         : 0.4547
# MSE         : 0.4952
# RMSE        : 0.7037
# R²          : 0.6221
# Adjusted R² : 0.6213
