# %%
# Model 4 – Ridge Regression

ridge = Ridge(alpha=1.0, random_state=42)

ridge_model, ridge_pred = evaluate_model(
    "Ridge Regression",
    ridge,
    X_train_scaled,
    X_test_scaled,
    y_train,
    y_test
)
# Out:
# Ridge Regression
# ----------------------------------------
# MAE         : 0.5332
# MSE         : 0.5559
# RMSE        : 0.7456
# R²          : 0.5758
# Adjusted R² : 0.575
